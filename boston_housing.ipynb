# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import boston_housing

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

scalar = StandardScaler()
train_data = scalar.fit_transform(train_data)
test_data = scalar.transform(test_data)

valid_data = train_data[:100]
valid_targets = train_targets[:100]
train_data = train_data[100:]
train_targets = train_targets[100:]

type(train_data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# numpy.ndarray

# %%
model = models.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(1)
])

# %%
model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])

# %% [markdown]
# # k=1-fold validation

# %%
history = model.fit(train_data, train_targets, epochs=20, batch_size=16, validation_data=(valid_data, valid_targets))
res = model.evaluate(test_data, test_targets, return_dict=True)
res
# Out:
# Epoch 1/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1664 - mae: 1.4930 - val_loss: 7.9119 - val_mae: 2.1618
# Epoch 2/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9964 - mae: 1.6829 - val_loss: 7.2853 - val_mae: 2.0452
# Epoch 3/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2646 - mae: 1.4452 - val_loss: 7.4506 - val_mae: 2.1005
# Epoch 4/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2513 - mae: 1.5098 - val_loss: 8.3025 - val_mae: 2.2321
# Epoch 5/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1277 - mae: 1.6188 - val_loss: 7.6140 - val_mae: 2.1011
# Epoch 6/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8278 - mae: 1.5925 - val_loss: 7.2125 - val_mae: 1.9878
# Epoch 7/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9862 - mae: 1.4945 - val_loss: 9.0050 - val_mae: 2.3771
# Epoch 8/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1979 - mae: 1.7051 - val_loss: 7.9221 - val_mae: 2.1467
# Epoch 9/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7672 - mae: 1.5835 - val_loss: 6.9241 - val_mae: 1.9209
# Epoch 10/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5838 - mae: 1.3759 - val_loss: 8.1864 - val_mae: 2.2067
# Epoch 11/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3580 - mae: 1.6964 - val_loss: 7.1278 - val_mae: 1.9815
# Epoch 12/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8036 - mae: 1.5915 - val_loss: 8.2935 - val_mae: 2.1778
# Epoch 13/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9246 - mae: 1.5606 - val_loss: 7.1272 - val_mae: 1.9558
# Epoch 14/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9059 - mae: 1.6763 - val_loss: 7.7407 - val_mae: 2.1363
# Epoch 15/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4405 - mae: 1.7710 - val_loss: 6.9509 - val_mae: 1.9012
# Epoch 16/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9642 - mae: 1.6226 - val_loss: 8.2772 - val_mae: 2.1858
# Epoch 17/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1081 - mae: 1.6282 - val_loss: 7.2271 - val_mae: 1.9454
# Epoch 18/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1381 - mae: 1.5917 - val_loss: 7.6547 - val_mae: 2.0105
# Epoch 19/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7206 - mae: 1.8411 - val_loss: 7.3567 - val_mae: 1.9970
# Epoch 20/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8665 - mae: 1.3660 - val_loss: 7.3323 - val_mae: 1.9854
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.3283 - mae: 2.4562
# {'loss': 18.164674758911133, 'mae': 2.6117475032806396}

# %% [markdown]
# # k-fold validation

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

scalar = StandardScaler()
train_data = scalar.fit_transform(train_data)
test_data = scalar.transform(test_data)

k = 8
s_len = len(train_data) // k
mae_list = []

for i in range(k):
    indices = np.arange(train_data.shape[0])  # Generate indices for the data
    np.random.shuffle(indices)  # Shuffle the indices randomly

    # Reorder both data and targets using the shuffled indices
    temp = train_data[indices]
    temp_targets = train_targets[indices]

    valid_data = temp[:i * s_len]
    valid_targets = temp_targets[:i * s_len]
    train_data = temp[i * s_len:]
    train_targets = temp_targets[i * s_len:]

    history = model.fit(temp, temp_targets, epochs=10, batch_size=16, validation_data=(valid_data, valid_targets))
    res = model.evaluate(test_data, test_targets, return_dict=True)

    mae_list.append(res["mae"])

avg_mae = np.mean(mae_list)
avg_mae

# %%
def build_model():
    model = models.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %%
def validate_k_fold(
    k: int,
    epochs: int,
    batch_size: int,
    train_data: np.ndarray,
    train_targets: np.ndarray,
    test_data: np.ndarray,
    test_targets: np.ndarray,
    model_builder
):
    if train_data is None or test_data is None or model_builder is None:
        raise ValueError("Missing arguments.")

    sample_size = len(train_data) // k
    samples = np.empty((k, sample_size, *train_data.shape[1:]))  # Adjust dimensions based on train_data shape
    targets = np.empty((k, sample_size), dtype=train_targets.dtype)

    # Split data into k folds
    for i in range(k):
        sample = train_data[i * sample_size: (i+1) * sample_size]
        target = train_targets[i * sample_size: (i+1) * sample_size]
        samples[i, :, :] = sample
        targets[i, :] = target  # Correct assignment

    mae_arr = np.zeros(k)

    for i in range(k):
        # Use all folds except the i-th fold for training
        partial_train_data = np.concatenate((samples[:i], samples[i+1:]), axis=0)
        partial_train_targets = np.concatenate((targets[:i], targets[i+1:]), axis=0)
        partial_valid_data = samples[i]
        partial_valid_targets = targets[i]

        # Build and train the model
        model = model_builder()
        model.fit(
            partial_train_data.reshape(-1, train_data.shape[1]),
            partial_train_targets.flatten(),
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(
                partial_valid_data.reshape(-1, train_data.shape[1]),
                partial_valid_targets.flatten()
            )
        )

        # Evaluate the model on the test set
        _, mae = model.evaluate(test_data, test_targets, verbose=0)
        mae_arr[i] = mae

    return np.mean(mae_arr)

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

scalar = StandardScaler()
train_data = scalar.fit_transform(train_data)
test_data = scalar.transform(test_data)

# %%
avg_mae = validate_k_fold(4, 20, 1, train_data, train_targets, test_data, test_targets, build_model)
avg_mae
# Out:
# Epoch 1/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 401.6525 - mae: 17.3260 - val_loss: 23.9113 - val_mae: 3.1571
# Epoch 2/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27.1917 - mae: 3.7169 - val_loss: 16.7709 - val_mae: 2.4826
# Epoch 3/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.6754 - mae: 2.9707 - val_loss: 13.0398 - val_mae: 2.4404
# Epoch 4/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.0464 - mae: 2.5662 - val_loss: 12.7909 - val_mae: 2.3936
# Epoch 5/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.1707 - mae: 2.6744 - val_loss: 11.7562 - val_mae: 2.2507
# Epoch 6/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6292 - mae: 2.3811 - val_loss: 10.4923 - val_mae: 2.1878
# Epoch 7/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9182 - mae: 2.5741 - val_loss: 10.9643 - val_mae: 2.2092
# Epoch 8/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.3763 - mae: 2.4041 - val_loss: 12.4103 - val_mae: 2.2594
# Epoch 9/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.8198 - mae: 2.3916 - val_loss: 9.5538 - val_mae: 2.1098
# Epoch 10/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14
# Epoch 8/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.5285 - mae: 2.5335 - val_loss: 15.0224 - val_mae: 2.5378
# Epoch 9/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.7577 - mae: 2.1993 - val_loss: 14.5479 - val_mae: 2.6368
# Epoch 10/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5464 - mae: 2.2223 - val_loss: 15.2035 - val_mae: 2.5553
# Epoch 11/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.4130 - mae: 2.0607 - val_loss: 16.2190 - val_mae: 2.7823
# Epoch 12/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0969 - mae: 2.0914 - val_loss: 15.0901 - val_mae: 2.5511
# Epoch 13/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8707 - mae: 2.0283 - val_loss: 15.1469 - val_mae: 2.6824
# Epoch 14/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.4452 - mae: 2.0154 - val_loss: 14.9900 - val_mae: 2.6361
# Epoch 15/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7156 - mae: 2.1450 - val_loss: 14.4522 - val_mae: 2.5170
# Epoch 16/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.2915 - mae: 1.8483 - val_loss: 13.9780 - val_mae: 2.5062
# Epoch 17/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.0761 - mae: 1.9667 - val_loss: 14.8598 - val_mae: 2.6151
# Epoch 18/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.9330 - mae: 1.9628 - val_loss: 15.6747 - val_mae: 2.7733
# Epoch 19/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2466 - mae: 1.9443 - val_loss: 14.6997 - val_mae: 2.6510
# Epoch 20/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7089 - mae: 1.8085 - val_loss: 14.1996 - val_mae: 2.6406
# Epoch 1/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 369.4547 - mae: 16.5461 - val_loss: 77.8870 - val_mae: 5.9632
# Epoch 2/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.7453 - mae: 3.8595 - val_loss: 50.0923 - val_mae: 4.6866
# Epoch 3/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.3213 - mae: 2.7879 - val_loss: 39.2411 - val_mae: 3.8618
# Epoch 4/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.9169 - mae: 2.8870 - val_loss: 35.4382 - val_mae: 3.5234
# Epoch 5/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.1061 - mae: 2.4756 - val_loss: 31.8050 - val_mae: 3.6019
# Epoch 6/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7914 - mae: 2.0346 - val_loss: 29.7780 - val_mae: 3.3899
# Epoch 7/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 21.6679 - mae: 2.8752 - val_loss: 26.3562 - val_mae: 3.0585
# Epoch 8/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.3450 - mae: 2.1855 - val_loss: 26.9541 - val_mae: 3.1375
# Epoch 9/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.2323 - mae: 2.2860 - val_loss: 25.7665 - val_mae: 3.0831
# Epoch 10/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.8905 - mae: 2.2824 - val_loss: 23.2082 - val_mae: 2.9245
# Epoch 11/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.2418 - mae: 2.1779 - val_loss: 23.2060 - val_mae: 3.0030
# Epoch 12/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6375 - mae: 1.9865 - val_loss: 21.2115 - val_mae: 2.8371
# Epoch 13/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.9990 - mae: 2.2573 - val_loss: 19.5762 - val_mae: 2.7654
# Epoch 14/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7909 - mae: 2.0141 - val_loss: 18.7145 - val_mae: 2.7501
# Epoch 15/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2663 - mae: 1.8774 - val_loss: 20.5203 - val_mae: 2.8492
# Epoch 16/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5763 - mae: 2.1600 - val_loss: 16.2113 - val_mae: 2.6052
# Epoch 17/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.9452 - mae: 2.1009 - val_loss: 15.0852 - val_mae: 2.5012
# Epoch 18/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9547 - mae: 1.8867 - val_loss: 16.6355 - val_mae: 2.6680
# Epoch 19/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.7341 - mae: 2.0366 - val_loss: 20.4282 - val_mae: 2.9679
# Epoch 20/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.8857 - mae: 1.9734 - val_loss: 16.6595 - val_mae: 2.6643
# 2.810963809490204
